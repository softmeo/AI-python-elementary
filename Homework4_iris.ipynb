# %% [markdown]
# # 1.1，请导入Python库

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.2，装载iris.csv文件

# %%
iris=pd.read_csv('iris.csv')

# %% [markdown]
# # 1.3，显示首部5行、尾部5行以及数据集统计信息

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      sepal length  sepal width  petal length  petal width         species  \
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      color
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2

# %%
iris.describe()
# Out:
#        sepal length  sepal width  petal length  petal width       color
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667    1.000000
# std        0.828066     0.433594      1.764420     0.763161    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# # 2.1，显示不同的" species"列的取值的个数
# 提示
#
# value_counts

# %%
iris['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# # 2.2 插入一列，名称为color
# 1,根据species的值，设定color列的值如下
#
# Iris-setosa  --> 0
#
# Iris-versicolor -->1
#
# Iris-virginica -->2
#
# 2，查看首部5行
#
# 3，查看50-55行
#
# 4，查看尾部5行

# %%
namebin = ['Iris-setosa','Iris-versicolor','Iris-virginica']
numbin = [0,1,2]
iris['color']= iris['species'].replace(namebin,numbin)

# %%
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width      species  color
# 0           5.1          3.5           1.4          0.2  Iris-setosa      0
# 1           4.9          3.0           1.4          0.2  Iris-setosa      0
# 2           4.7          3.2           1.3          0.2  Iris-setosa      0
# 3           4.6          3.1           1.5          0.2  Iris-setosa      0
# 4           5.0          3.6           1.4          0.2  Iris-setosa      0

# %%
iris.loc[50:55,:]
# Out:
#     sepal length  sepal width  petal length  petal width          species  \
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor
# 55           5.7          2.8           4.5          1.3  Iris-versicolor
#
#     color
# 50      1
# 51      1
# 52      1
# 53      1
# 54      1
# 55      1

# %%
iris.tail()
# Out:
#      sepal length  sepal width  petal length  petal width         species  \
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      color
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2

# %% [markdown]
# # 3，把所有的样本点用scatter显示
# 1，横坐标为不同的sepal length、或者sepal width、或者petal length、或者sepal width
#
# 2，纵坐标为1、2、3(对应Iris-setosa、Iris-versicolor、Iris-virginica)，提示用到刚才建立的color列
#
# 3，三点颜色为1、2、3(对应Iris-setosa、Iris-versicolor、Iris-virginica)，提示用到刚才建立的color列
#
# 4，看看用单独一个属性，是否可以分开各个类别，也就是横向上不同类别的散点集有没有overlap
#
# 5，总共画四个图
# x = 'sepal length'，y= iris_data['color']
# x = 'sepal width'，y= iris_data['color']
# x = 'petal length'，y= iris_data['color']
# x = 'sepal width'，y= iris_data['color']

# %%
the_x = iris['sepal length']
the_y = iris['color'] + 1
the_color = iris['color']
plt.scatter(the_x,the_y,c=the_color,marker='o',edgecolors='black')
plt.show()

# %%
the_x = iris['sepal width']
the_y = iris['color'] + 1
the_color = iris['color']
plt.scatter(the_x,the_y,c=the_color,marker='o',edgecolors='black')
plt.show()

# %%
the_x = iris['petal length']
the_y = iris['color'] + 1
the_color = iris['color']
plt.scatter(the_x,the_y,c=the_color,marker='o',edgecolors='black')
plt.show()

# %%
the_x = iris['petal width']
the_y = iris['color'] + 1
the_color = iris['color']
plt.scatter(the_x,the_y,c=the_color,marker='o',edgecolors='black')
plt.show()

# %% [markdown]
# # 4，把所有的样本点用scatter显示
# 1,横坐标，从[sepal length,sepal width,petal length,petal width]选择一个属性
#
# 2,纵坐标，从[sepal length,sepal width,petal length,petal width]选择另一个属性
#
# 提示，也就是横坐标和纵坐标是[sepal length,sepal width,petal length,petal width]的两两组合，比如sepal length-sepal length，但是不要跟自己组合，比如sepal length-sepal length
# (组合总数为6种)
#
# 3,散点颜色为1、2、3，分别表示Iris-setosa、Iris-versicolor、Iris-virginica
#
# 4,看看各个类别时间是否有比较清晰的分类边界，考察两个属性是否可以把各个类别分开

# %%
the_bin=['sepal length','sepal width','petal length','petal width']
cnt = 1
for i in range(4):
    for j in range(4):
        if(i>=j):
            continue
        x = iris[the_bin[i]]
        y = iris[the_bin[j]]
        the_color = iris['color']
        plt.xlabel(the_bin[i])
        plt.ylabel(the_bin[j])
        plt.title(str(cnt))
        plt.scatter(x,y,c=the_color,marker='o',edgecolors='black')
        plt.show()
        cnt+=1

# %% [markdown]
# # 5，用seaborn实现第四题的要求
# # 把所有的样本点用scatter显示
# 1,横坐标，从[sepal length,sepal width,petal length,petal width]选择一个属性
#
# 2,纵坐标，从[sepal length,sepal width,petal length,petal width]选择另一个属性
#
# 提示，也就是横坐标和纵坐标是[sepal length,sepal width,petal length,petal width]的两两组合，比如sepal length-sepal length，但是不要跟自己组合，比如sepal length-sepal length
#
# 3,散点颜色为1、2、3，分别表示Iris-setosa、Iris-versicolor、Iris-virginica
#
# 4,看看各个类别时间是否有比较清晰的分类边界，考察两个属性是否可以把各个类别分开

# %%
iris_new = iris.drop('color',axis = 1)
sns.set_style('darkgrid')
sns.pairplot(iris_new,hue='species')
plt.show()
